# %%
import pandas as pd
  
matri = pd.read_stata('https://github.com/Proyecto-Magallanes/Dashboard/raw/main/data/matrimonio.dta')
embara2022 = pd.read_stata('https://github.com/Proyecto-Magallanes/Dashboard/raw/main/data/embarazo-2022.dta')
embara2021 = pd.read_stata('https://github.com/Proyecto-Magallanes/Dashboard/raw/main/data/embarazo.dta')
embara2020 = pd.read_stata('https://github.com/Proyecto-Magallanes/Dashboard/raw/main/data/embarazo-2020.dta')
embara2019 = pd.read_stata('https://github.com/Proyecto-Magallanes/Dashboard/raw/main/data/embarazo-2019.dta')

# %%
embara2022['year'] = '2022_emba'
embara2021['year'] = '2021_emba'
embara2020['year'] = '2020_emba'
embara2019['year'] = '2019_emba'

# %%
df = pd.concat([embara2022, embara2021, embara2020, embara2019], ignore_index=True)
df
# Out:
#           V023    embara       year
# 0     Amazonas  4.443319  2022_emba
# 1       Ancash  0.301272  2022_emba
# 2     Apurimac  3.054922  2022_emba
# 3     Arequipa  1.212529  2022_emba
# 4     Ayacucho  2.074109  2022_emba
# ..         ...       ...        ...
# 95        Puno  0.293140  2019_emba
# 96  San_Martin  4.509174  2019_emba
# 97       Tacna  1.683604  2019_emba
# 98      Tumbes  2.644926  2019_emba
# 99     Ucayali  2.048910  2019_emba
#
# [100 rows x 3 columns]

# %%
df['V023'] = df['V023'].str.upper().str.strip()
df['V023'] = df['V023'].str.replace('_',' ')

# %%
# to wide
df=pd.pivot_table(df,
               values='embara', # values to use
               index=['V023'], # unit of analysis
               columns=['year']) # the values for NEW column
# see wide
df
# Out:
# year           2019_emba  2020_emba  2021_emba  2022_emba
# V023
# AMAZONAS        6.594434   2.287450   2.837393   4.443319
# ANCASH          2.251308   1.451668   0.601753   0.301272
# APURIMAC        1.292593   1.477868   5.648242   3.054922
# AREQUIPA        1.400310   0.385852   3.010771   1.212529
# AYACUCHO        2.190061   1.489757   2.198520   2.074109
# CAJAMARCA       1.732945   4.119957   3.208621   2.272505
# CALLAO          0.000000   1.627594   3.100111   3.420131
# CUSCO           1.920599   1.388067   0.000000   1.377489
# HUANCAVELICA    1.092259   1.380500   2.915410   2.072900
# HUANUCO         3.229900   0.285387   0.988595   3.428313
# ICA             3.108135   5.335292   3.328177   3.149382
# JUNIN           2.391656   2.216271   2.941517   2.634570
# LA LIBERTAD     0.915909   0.173688   5.333999   1.648129
# LAMBAYEQUE      4.721803   2.981337   2.292395   0.478010
# LIMA            0.930489   1.587999   1.252107   0.670876
# LORETO          5.952281   0.259528   4.937203   3.474855
# MADRE DE DIOS   4.636341   0.489408   6.448959   1.281081
# MOQUEGUA        0.317120   0.000000   1.577186   3.498047
# PASCO           3.816348   0.417125   1.441410   3.403510
# PIURA           3.161887   2.053235   0.969380   0.723785
# PUNO            0.293140   1.449460   0.878504   2.365903
# SAN MARTIN      4.509174   3.506483   2.080905   3.251802
# TACNA           1.683604   0.000000   1.663377   2.714049
# TUMBES          2.644926   7.393826   3.429705   1.296588
# UCAYALI         2.048910   1.914962   6.782629   4.713962

# %%
df= df.reset_index(drop=False).\
             rename_axis(index=None, columns=None) # no name for indexes

# %%
df=df.rename(columns={'V023':'DEPARTAMEN'})
df
# Out:
#        DEPARTAMEN  2019_emba  2020_emba  2021_emba  2022_emba
# 0        AMAZONAS   6.594434   2.287450   2.837393   4.443319
# 1          ANCASH   2.251308   1.451668   0.601753   0.301272
# 2        APURIMAC   1.292593   1.477868   5.648242   3.054922
# 3        AREQUIPA   1.400310   0.385852   3.010771   1.212529
# 4        AYACUCHO   2.190061   1.489757   2.198520   2.074109
# 5       CAJAMARCA   1.732945   4.119957   3.208621   2.272505
# 6          CALLAO   0.000000   1.627594   3.100111   3.420131
# 7           CUSCO   1.920599   1.388067   0.000000   1.377489
# 8    HUANCAVELICA   1.092259   1.380500   2.915410   2.072900
# 9         HUANUCO   3.229900   0.285387   0.988595   3.428313
# 10            ICA   3.108135   5.335292   3.328177   3.149382
# 11          JUNIN   2.391656   2.216271   2.941517   2.634570
# 12    LA LIBERTAD   0.915909   0.173688   5.333999   1.648129
# 13     LAMBAYEQUE   4.721803   2.981337   2.292395   0.478010
# 14           LIMA   0.930489   1.587999   1.252107   0.670876
# 15         LORETO   5.952281   0.259528   4.937203   3.474855
# 16  MADRE DE DIOS   4.636341   0.489408   6.448959   1.281081
# 17       MOQUEGUA   0.317120   0.000000   1.577186   3.498047
# 18          PASCO   3.816348   0.417125   1.441410   3.403510
# 19          PIURA   3.161887   2.053235   0.969380   0.723785
# 20           PUNO   0.293140   1.449460   0.878504   2.365903
# 21     SAN MARTIN   4.509174   3.506483   2.080905   3.251802
# 22          TACNA   1.683604   0.000000   1.663377   2.714049
# 23         TUMBES   2.644926   7.393826   3.429705   1.296588
# 24        UCAYALI   2.048910   1.914962   6.782629   4.713962

# %%
df[['2019_emba','2020_emba','2021_emba','2022_emba']]=df[['2019_emba','2020_emba','2021_emba','2022_emba']]. apply(pd.to_numeric)

# %%
#Data Scaling
columnsToScale=['2019_emba','2020_emba','2021_emba','2022_emba'] # you can add more columns

from sklearn import preprocessing

minmaxSc = preprocessing.MinMaxScaler(feature_range=(0, 10))

minmaxResult = minmaxSc.fit_transform(df[columnsToScale])

minmaxResult
# Out:
# array([[10.        ,  3.0937302 ,  4.183324  ,  9.386672  ],
#        [ 3.4139519 ,  1.963352  ,  0.8871977 ,  0.        ],
#        [ 1.9601271 ,  1.9987866 ,  8.327513  ,  6.2402973 ],
#        [ 2.123472  ,  0.52185714,  4.4389443 ,  2.065083  ],
#        [ 3.3210752 ,  2.014866  ,  3.2413988 ,  4.017588  ],
#        [ 2.62789   ,  5.572159  ,  4.7306447 ,  4.4671907 ],
#        [ 0.        ,  2.2012877 ,  4.5706635 ,  7.067931  ],
#        [ 2.9124553 ,  1.8773323 ,  0.        ,  2.4389148 ],
#        [ 1.656335  ,  1.8670988 ,  4.298348  ,  4.0148473 ],
#        [ 4.8979177 ,  0.38597992,  1.4575403 ,  7.0864744 ],
#        [ 4.7132697 ,  7.2158747 ,  4.9069133 ,  6.4543624 ],
#        [ 3.6267798 ,  2.997462  ,  4.3368387 ,  5.2876987 ],
#        [ 1.3889129 ,  0.23490973,  7.864206  ,  3.052236  ],
#        [ 7.160285  ,  4.032197  ,  3.379803  ,  0.400522  ],
#        [ 1.4110222 ,  2.1477358 ,  1.8460491 ,  0.83759344],
#        [ 9.026219  ,  0.35100642,  7.2791886 ,  7.191946  ],
#        [ 7.030688  ,  0.6619137 ,  9.508052  ,  2.2204342 ],
#        [ 0.48089102,  0.        ,  2.325332  ,  7.244504  ],
#        [ 5.7872252 ,  0.5641527 ,  2.1251502 ,  7.030265  ],
#        [ 4.794782  ,  2.7769587 ,  1.4292096 ,  0.9574959 ],
#        [ 0.44452626,  1.9603653 ,  1.2952261 ,  4.6788487 ],
#        [ 6.837848  ,  4.7424474 ,  3.0679917 ,  6.686465  ],
#        [ 2.5530684 ,  0.        ,  2.452408  ,  5.4678144 ],
#        [ 4.0108457 , 10.        ,  5.056602  ,  2.255577  ],
#        [ 3.107029  ,  2.5899477 , 10.        , 10.        ]],
#       dtype=float32)

# %%
df['Total_minMax_2019']=minmaxResult[:, 0]
df['Total_minMax_2020']=minmaxResult[:, 1]
df['Total_minMax_2021']=minmaxResult[:, 2]
df['Total_minMax_2022']=minmaxResult[:, 3]

# %%
#Empezamos con el Mapa
import geopandas as gpd
import os

Peru=gpd.read_file(os.path.join("mapas", "peruMaps.gpkg"))

# %%
theMap=Peru.merge(df,on='DEPARTAMEN')
theMap
# Out:
#    IDDPTO     DEPARTAMEN           CAPITAL FUENTE  \
# 0      01       AMAZONAS       CHACHAPOYAS   INEI
# 1      02         ANCASH            HUARAZ   INEI
# 2      03       APURIMAC           ABANCAY   INEI
# 3      04       AREQUIPA          AREQUIPA   INEI
# 4      05       AYACUCHO          AYACUCHO   INEI
# 5      06      CAJAMARCA         CAJAMARCA   INEI
# 6      07         CALLAO            CALLAO   INEI
# 7      08          CUSCO             CUSCO   INEI
# 8      09   HUANCAVELICA      HUANCAVELICA   INEI
# 9      10        HUANUCO           HUANUCO   INEI
# 10     11            ICA               ICA   INEI
# 11     12          JUNIN          HUANCAYO   INEI
# 12     13    LA LIBERTAD          TRUJILLO   INEI
# 13     14     LAMBAYEQUE          CHICLAYO   INEI
# 14     15           LIMA              LIMA   INEI
# 15     16         LORETO           IQUITOS   INEI
# 16     17  MADRE DE DIOS  PUERTO MALDONADO   INEI
# 17     18       MOQUEGUA          MOQUEGUA   INEI
# 18     19          PASCO    CERRO DE PASCO   INEI
# 19     20          PIURA             PIURA   INEI
# 20     21           PUNO              PUNO   INEI
# 21     22     SAN MARTIN         MOYOBAMBA   INEI
# 22     23          TACNA             TACNA   INEI
# 23     24         TUMBES            TUMBES   INEI
# 24     25        UCAYALI          PUCALLPA   INEI
#
#                                              geometry  2019_emba  2020_emba  \
# 0   POLYGON ((-77.81211 -2.98962, -77.81332 -2.990...   6.594434   2.287450
# 1   POLYGON ((-77.64692 -8.05086, -77.64669 -8.052...   2.251308   1.451668
# 2   POLYGON ((-73.74632 -13.17456, -73.74570 -13.1...   1.292593   1.477868
# 3   POLYGON ((-71.98109 -14.64062, -71.98093 -14.6...   1.400310   0.385852
# 4   POLYGON ((-74.34843 -12.17503, -74.35000 -12.1...   2.190061   1.489757
# 5   POLYGON ((-78.70034 -4.62769, -78.69817 -4.629...   1.732945   4.119957
# 6   POLYGON ((-77.13521 -11.81782, -77.13516 -11.8...   0.000000   1.627594
# 7   POLYGON ((-72.97280 -11.25189, -72.97134 -11.2...   1.920599   1.388067
# 8   POLYGON ((-74.57118 -11.98710, -74.57095 -11.9...   1.092259   1.380500
# 9   POLYGON ((-76.00486 -8.30517, -76.00301 -8.305...   3.229900   0.285387
# 10  POLYGON ((-75.61136 -12.96649, -75.61103 -12.9...   3.108135   5.335292
# 11  POLYGON ((-75.03564 -10.68232, -75.03436 -10.6...   2.391656   2.216271
# 12  POLYGON ((-77.75753 -6.96579, -77.75638 -6.967...   0.915909   0.173688
# 13  POLYGON ((-79.88373 -5.49283, -79.88265 -5.494...   4.721803   2.981337
# 14  MULTIPOLYGON (((-76.78117 -12.40917, -76.78144...   0.930489   1.587999
# 15  POLYGON ((-75.10004 -0.08096, -75.09485 -0.081...   5.952281   0.259528
# 16  POLYGON ((-70.61346 -10.12964, -70.61359 -10.2...   4.636341   0.489408
# 17  POLYGON ((-70.79388 -15.98721, -70.79486 -15.9...   0.317120   0.000000
# 18  POLYGON ((-74.68005 -9.44727, -74.67872 -9.448...   3.816348   0.417125
# 19  POLYGON ((-80.48552 -4.08443, -80.48403 -4.085...   3.161887   2.053235
# 20  MULTIPOLYGON (((-68.81422 -16.34799, -68.91839...   0.293140   1.449460
# 21  POLYGON ((-77.71678 -5.41597, -77.71270 -5.416...   4.509174   3.506483
# 22  POLYGON ((-70.26604 -16.77955, -70.26474 -16.7...   1.683604   0.000000
# 23  POLYGON ((-80.28521 -3.41276, -80.28406 -3.412...   2.644926   7.393826
# 24  POLYGON ((-74.47145 -7.27617, -74.47052 -7.277...   2.048910   1.914962
#
#     2021_emba  2022_emba  Total_minMax_2019  Total_minMax_2020  \
# 0    2.837393   4.443319          10.000000           3.093730
# 1    0.601753   0.301272           3.413952           1.963352
# 2    5.648242   3.054922           1.960127           1.998787
# 3    3.010771   1.212529           2.123472           0.521857
# 4    2.198520   2.074109           3.321075           2.014866
# 5    3.208621   2.272505           2.627890           5.572159
# 6    3.100111   3.420131           0.000000           2.201288
# 7    0.000000   1.377489           2.912455           1.877332
# 8    2.915410   2.072900           1.656335           1.867099
# 9    0.988595   3.428313           4.897918           0.385980
# 10   3.328177   3.149382           4.713270           7.215875
# 11   2.941517   2.634570           3.626780           2.997462
# 12   5.333999   1.648129           1.388913           0.234910
# 13   2.292395   0.478010           7.160285           4.032197
# 14   1.252107   0.670876           1.411022           2.147736
# 15   4.937203   3.474855           9.026219           0.351006
# 16   6.448959   1.281081           7.030688           0.661914
# 17   1.577186   3.498047           0.480891           0.000000
# 18   1.441410   3.403510           5.787225           0.564153
# 19   0.969380   0.723785           4.794782           2.776959
# 20   0.878504   2.365903           0.444526           1.960365
# 21   2.080905   3.251802           6.837848           4.742447
# 22   1.663377   2.714049           2.553068           0.000000
# 23   3.429705   1.296588           4.010846          10.000000
# 24   6.782629   4.713962           3.107029           2.589948
#
#     Total_minMax_2021  Total_minMax_2022
# 0            4.183324           9.386672
# 1            0.887198           0.000000
# 2            8.327513           6.240297
# 3            4.438944           2.065083
# 4            3.241399           4.017588
# 5            4.730645           4.467191
# 6            4.570663           7.067931
# 7            0.000000           2.438915
# 8            4.298348           4.014847
# 9            1.457540           7.086474
# 10           4.906913           6.454362
# 11           4.336839           5.287699
# 12           7.864206           3.052236
# 13           3.379803           0.400522
# 14           1.846049           0.837593
# 15           7.279189           7.191946
# 16           9.508052           2.220434
# 17           2.325332           7.244504
# 18           2.125150           7.030265
# 19           1.429210           0.957496
# 20           1.295226           4.678849
# 21           3.067992           6.686465
# 22           2.452408           5.467814
# 23           5.056602           2.255577
# 24          10.000000          10.000000

# %%
#Intervalos
import mapclassify 
import numpy as np

np.random.seed(12345) # so we all get the same results!

# let's try 5 intervals
K=4
theVar2019=theMap.Total_minMax_2019
theVar2020=theMap.Total_minMax_2020
theVar2021=theMap.Total_minMax_2021
theVar2022=theMap.Total_minMax_2022
# based on similarity, optimizer
mp52019 = mapclassify.MaxP(theVar2019, k=K) 
mp52020 = mapclassify.MaxP(theVar2020, k=K) 
mp52021 = mapclassify.MaxP(theVar2021, k=K) 
mp52022 = mapclassify.MaxP(theVar2022, k=K)

# %%
theMap['Total_mp52019'] = mp52019.yb
theMap['Total_mp52020'] = mp52020.yb
theMap['Total_mp52021'] = mp52021.yb
theMap['Total_mp52022'] = mp52022.yb
theMap
# Out:
#    IDDPTO     DEPARTAMEN           CAPITAL FUENTE  \
# 0      01       AMAZONAS       CHACHAPOYAS   INEI
# 1      02         ANCASH            HUARAZ   INEI
# 2      03       APURIMAC           ABANCAY   INEI
# 3      04       AREQUIPA          AREQUIPA   INEI
# 4      05       AYACUCHO          AYACUCHO   INEI
# 5      06      CAJAMARCA         CAJAMARCA   INEI
# 6      07         CALLAO            CALLAO   INEI
# 7      08          CUSCO             CUSCO   INEI
# 8      09   HUANCAVELICA      HUANCAVELICA   INEI
# 9      10        HUANUCO           HUANUCO   INEI
# 10     11            ICA               ICA   INEI
# 11     12          JUNIN          HUANCAYO   INEI
# 12     13    LA LIBERTAD          TRUJILLO   INEI
# 13     14     LAMBAYEQUE          CHICLAYO   INEI
# 14     15           LIMA              LIMA   INEI
# 15     16         LORETO           IQUITOS   INEI
# 16     17  MADRE DE DIOS  PUERTO MALDONADO   INEI
# 17     18       MOQUEGUA          MOQUEGUA   INEI
# 18     19          PASCO    CERRO DE PASCO   INEI
# 19     20          PIURA             PIURA   INEI
# 20     21           PUNO              PUNO   INEI
# 21     22     SAN MARTIN         MOYOBAMBA   INEI
# 22     23          TACNA             TACNA   INEI
# 23     24         TUMBES            TUMBES   INEI
# 24     25        UCAYALI          PUCALLPA   INEI
#
#                                              geometry  2019_emba  2020_emba  \
# 0   POLYGON ((-77.81211 -2.98962, -77.81332 -2.990...   6.594434   2.287450
# 1   POLYGON ((-77.64692 -8.05086, -77.64669 -8.052...   2.251308   1.451668
# 2   POLYGON ((-73.74632 -13.17456, -73.74570 -13.1...   1.292593   1.477868
# 3   POLYGON ((-71.98109 -14.64062, -71.98093 -14.6...   1.400310   0.385852
# 4   POLYGON ((-74.34843 -12.17503, -74.35000 -12.1...   2.190061   1.489757
# 5   POLYGON ((-78.70034 -4.62769, -78.69817 -4.629...   1.732945   4.119957
# 6   POLYGON ((-77.13521 -11.81782, -77.13516 -11.8...   0.000000   1.627594
# 7   POLYGON ((-72.97280 -11.25189, -72.97134 -11.2...   1.920599   1.388067
# 8   POLYGON ((-74.57118 -11.98710, -74.57095 -11.9...   1.092259   1.380500
# 9   POLYGON ((-76.00486 -8.30517, -76.00301 -8.305...   3.229900   0.285387
# 10  POLYGON ((-75.61136 -12.96649, -75.61103 -12.9...   3.108135   5.335292
# 11  POLYGON ((-75.03564 -10.68232, -75.03436 -10.6...   2.391656   2.216271
# 12  POLYGON ((-77.75753 -6.96579, -77.75638 -6.967...   0.915909   0.173688
# 13  POLYGON ((-79.88373 -5.49283, -79.88265 -5.494...   4.721803   2.981337
# 14  MULTIPOLYGON (((-76.78117 -12.40917, -76.78144...   0.930489   1.587999
# 15  POLYGON ((-75.10004 -0.08096, -75.09485 -0.081...   5.952281   0.259528
# 16  POLYGON ((-70.61346 -10.12964, -70.61359 -10.2...   4.636341   0.489408
# 17  POLYGON ((-70.79388 -15.98721, -70.79486 -15.9...   0.317120   0.000000
# 18  POLYGON ((-74.68005 -9.44727, -74.67872 -9.448...   3.816348   0.417125
# 19  POLYGON ((-80.48552 -4.08443, -80.48403 -4.085...   3.161887   2.053235
# 20  MULTIPOLYGON (((-68.81422 -16.34799, -68.91839...   0.293140   1.449460
# 21  POLYGON ((-77.71678 -5.41597, -77.71270 -5.416...   4.509174   3.506483
# 22  POLYGON ((-70.26604 -16.77955, -70.26474 -16.7...   1.683604   0.000000
# 23  POLYGON ((-80.28521 -3.41276, -80.28406 -3.412...   2.644926   7.393826
# 24  POLYGON ((-74.47145 -7.27617, -74.47052 -7.277...   2.048910   1.914962
#
#     2021_emba  2022_emba  Total_minMax_2019  Total_minMax_2020  \
# 0    2.837393   4.443319          10.000000           3.093730
# 1    0.601753   0.301272           3.413952           1.963352
# 2    5.648242   3.054922           1.960127           1.998787
# 3    3.010771   1.212529           2.123472           0.521857
# 4    2.198520   2.074109           3.321075           2.014866
# 5    3.208621   2.272505           2.627890           5.572159
# 6    3.100111   3.420131           0.000000           2.201288
# 7    0.000000   1.377489           2.912455           1.877332
# 8    2.915410   2.072900           1.656335           1.867099
# 9    0.988595   3.428313           4.897918           0.385980
# 10   3.328177   3.149382           4.713270           7.215875
# 11   2.941517   2.634570           3.626780           2.997462
# 12   5.333999   1.648129           1.388913           0.234910
# 13   2.292395   0.478010           7.160285           4.032197
# 14   1.252107   0.670876           1.411022           2.147736
# 15   4.937203   3.474855           9.026219           0.351006
# 16   6.448959   1.281081           7.030688           0.661914
# 17   1.577186   3.498047           0.480891           0.000000
# 18   1.441410   3.403510           5.787225           0.564153
# 19   0.969380   0.723785           4.794782           2.776959
# 20   0.878504   2.365903           0.444526           1.960365
# 21   2.080905   3.251802           6.837848           4.742447
# 22   1.663377   2.714049           2.553068           0.000000
# 23   3.429705   1.296588           4.010846          10.000000
# 24   6.782629   4.713962           3.107029           2.589948
#
#     Total_minMax_2021  Total_minMax_2022  Total_mp52019  Total_mp52020  \
# 0            4.183324           9.386672              3              3
# 1            0.887198           0.000000              1              0
# 2            8.327513           6.240297              0              1
# 3            4.438944           2.065083              0              0
# 4            3.241399           4.017588              0              1
# 5            4.730645           4.467191              0              3
# 6            4.570663           7.067931              0              2
# 7            0.000000           2.438915              0              0
# 8            4.298348           4.014847              0              0
# 9            1.457540           7.086474              3              0
# 10           4.906913           6.454362              1              3
# 11           4.336839           5.287699              1              2
# 12           7.864206           3.052236              0              0
# 13           3.379803           0.400522              3              3
# 14           1.846049           0.837593              0              1
# 15           7.279189           7.191946              3              0
# 16           9.508052           2.220434              3              0
# 17           2.325332           7.244504              0              0
# 18           2.125150           7.030265              3              0
# 19           1.429210           0.957496              2              2
# 20           1.295226           4.678849              0              0
# 21           3.067992           6.686465              3              3
# 22           2.452408           5.467814              0              0
# 23           5.056602           2.255577              1              3
# 24          10.000000          10.000000              0              2
#
#     Total_mp52021  Total_mp52022
# 0               1              3
# 1               0              0
# 2               2              1
# 3               1              0
# 4               0              0
# 5               2              0
# 6               1              3
# 7               0              0
# 8               1              0
# 9               0              3
# 10              2              1
# 11              1              1
# 12              2              0
# 13              0              0
# 14              0              0
# 15              2              3
# 16              2              0
# 17              0              3
# 18              0              2
# 19              0              0
# 20              0              1
# 21              0              2
# 22              0              1
# 23              2              0
# 24              3              3

# %%
changes={0:"0_Muy Bajo", 1:"1_Bajo", 2:"2_Alto", 3:"3_Muy Alto"}
theMap[['Total_mp52019', 'Total_mp52020', 'Total_mp52021', 'Total_mp52022']]=theMap.loc[:,['Total_mp52019', 'Total_mp52020', 'Total_mp52021', 'Total_mp52022']].replace(to_replace=changes)

# %%
theMap.to_file(os.path.join("mapas","PeruMapa2019_2022.gpkg"), layer='peru', driver="GPKG")

# %%
#rescalando
theMap=theMap.to_crs(8858)
theMap['centroid']=theMap.geometry.centroid

# %%
import matplotlib.pyplot as plt

f, ax = plt.subplots(1, figsize=(10, 10))
theMap.plot(column='Total_msd_embara', 
        cmap='coolwarm', 
        categorical=True,
        edgecolor='grey', 
        linewidth=0.1, 
        alpha=0.75, 
        legend=True,
        legend_kwds={'loc':3},
        ax=ax
       )

ax.set_axis_off()

# %%
# just the plot

f, ax = plt.subplots(1, figsize=(8, 8))
base=theMap.plot(column='Total_msd_embara', 
        cmap='Greens', 
        categorical=True,
        edgecolor='grey', 
        linewidth=0.1, 
        alpha=0.75, 
        legend=True,
        legend_kwds={'loc':3},
        ax=ax
       )

# another column, with the size of the POINTS (based on "Total_ei5")
theMap["sizeOfMarker_msd_matri"]=[4**exp for exp in theMap["Total_msd_matri"]]

# now, plotting the centroids (declared as the geometry)!!!
mapa1 = theMap.set_geometry("centroid").plot(column="Total_msd_matri",
                                         categorical=True,
                                         markersize=theMap["sizeOfMarker_msd_matri"],
                                         cmap='Reds',
                                         edgecolor='grey',
                                         linewidth=0.5,
                                         legend=True,
                                         ax=base)
#plt.savefig(os.path.join("imagenes","mapa1.png"))

# %%
import seaborn as sns


f, ax = plt.subplots(1, figsize=(8, 8))

# Trazar todas las regiones en gris con bordes notables
theMap.boundary.plot(ax=ax, color='grey', linewidth=0.5, alpha=0.75)

# Filtrar las regiones con una alta tasa de embarazo (por ejemplo, con una tasa mayor a un cierto umbral)
umbral_embarazo = 2  # Ajusta el umbral según tus datos
regiones_altas_embarazo = theMap[theMap['Total_msd_embara'] > umbral_embarazo]

# Calcular el tamaño de los centroides basado en Total_msd_matri
regiones_altas_embarazo.loc[:, "sizeOfMarker_msd_matri"] = 4 ** regiones_altas_embarazo["Total_msd_matri"]


# Trazar solo las regiones con alta tasa de embarazo en verde
regiones_altas_embarazo.plot(column='Total_msd_embara', 
                             cmap='coolwarm', 
                             categorical=True,
                             edgecolor='grey',  # Establecer el color del borde en negro
                             linewidth=0.01,  # Aumentar el ancho del borde
                             alpha=0.75, 
                             legend=True,
                             legend_kwds={'loc': 3},
                             ax=ax
                            )

# Trazar los centroides solo en las regiones con alta tasa de embarazo con tamaños variables
regiones_altas_embarazo.set_geometry("centroid").plot(column="Total_msd_matri",
                                                      categorical=True,
                                                      markersize="sizeOfMarker_msd_matri",  # Tamaño variable basado en la nueva columna
                                                      cmap='viridis',
                                                      edgecolor='grey',  # Establecer el color del borde en negro
                                                      linewidth=0.3,  # Aumentar el ancho del borde
                                                      legend=True,
                                                      ax=ax
                                                     )


plt.savefig(os.path.join("imagenes","mapa2.png"))

# %%
#plt.savefig(os.path.join("imagenes","mapa1.png"))
# save the map as image (create "images" folder first)
#plt.savefig(os.path.join("images",'Brasil_3layers.jpg'))
