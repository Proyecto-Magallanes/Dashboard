# %%
# pip install openpyxl --upgrade

# %%
import pandas as pd
  
df = pd.read_stata('https://github.com/Proyecto-Magallanes/Dashboard/raw/main/data/embarazo.dta')
df
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_stata('https://github.com/Proyecto-Magallanes/Dashboard/raw/main/data/embarazo.dta')
#       4 df
#
# File ~\.conda\envs\taller\Lib\site-packages\pandas\io\stata.py:2150, in read_stata(filepath_or_buffer, convert_dates, convert_categoricals, index_col, convert_missing, preserve_dtypes, columns, order_categoricals, chunksize, iterator, compression, storage_options)
#    2147     return reader
#    2149 with reader:
# -> 2150     return reader.read()
#
# File ~\.conda\envs\taller\Lib\site-packages\pandas\io\stata.py:1708, in StataReader.read(self, nrows, convert_dates, convert_categoricals, index_col, convert_missing, preserve_dtypes, columns, order_categoricals)
#    1696 @Appender(_read_method_doc)
#    1697 def read(
#    1698     self,
#    (...)
#    1706     order_categoricals: bool | None = None,
#    1707 ) -> DataFrame:
# -> 1708     self._ensure_open()
#    1710     # Handle options
#    1711     if convert_dates is None:
#
# File ~\.conda\envs\taller\Lib\site-packages\pandas\io\stata.py:1182, in StataReader._ensure_open(self)
#    1178 """
#    1179 Ensure the file has been opened and its header data read.
#    1180 """
#    1181 if not hasattr(self, "_path_or_buf"):
# -> 1182     self._open_file()
#
# File ~\.conda\envs\taller\Lib\site-packages\pandas\io\stata.py:1195, in StataReader._open_file(self)
#    1188 if not self._entered:
#    1189     warnings.warn(
#    1190         "StataReader is being used without using a context manager. "
#    1191         "Using StataReader as a context manager is the only supported method.",
#    1192         ResourceWarning,
#    1193         stacklevel=find_stack_level(),
#    1194     )
# -> 1195 handles = get_handle(
#    1196     self._original_path_or_buf,
#    1197     "rb",
#    1198     storage_options=self._storage_options,
#    1199     is_text=False,
#    1200     compression=self._compression,
#    1201 )
#    1202 if hasattr(handles.handle, "seekable") and handles.handle.seekable():
#    1203     # If the handle is directly seekable, use it without an extra copy.
#    1204     self._path_or_buf = handles.handle
#
# File ~\.conda\envs\taller\Lib\site-packages\pandas\io\common.py:718, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     715     codecs.lookup_error(errors)
#     717 # open URLs
# --> 718 ioargs = _get_filepath_or_buffer(
#     719     path_or_buf,
#     720     encoding=encoding,
#     721     compression=compression,
#     722     mode=mode,
#     723     storage_options=storage_options,
#     724 )
#     726 handle = ioargs.filepath_or_buffer
#     727 handles: list[BaseBuffer]
#
# File ~\.conda\envs\taller\Lib\site-packages\pandas\io\common.py:372, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     370 # assuming storage_options is to be interpreted as headers
#     371 req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 372 with urlopen(req_info) as req:
#     373     content_encoding = req.headers.get("Content-Encoding", None)
#     374     if content_encoding == "gzip":
#     375         # Override compression based on Content-Encoding header
#
# File ~\.conda\envs\taller\Lib\site-packages\pandas\io\common.py:274, in urlopen(*args, **kwargs)
#     268 """
#     269 Lazy-import wrapper for stdlib urlopen, as that imports a big chunk of
#     270 the stdlib.
#     271 """
#     272 import urllib.request
# --> 274 return urllib.request.urlopen(*args, **kwargs)
#
# File ~\.conda\envs\taller\Lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~\.conda\envs\taller\Lib\urllib\request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File ~\.conda\envs\taller\Lib\urllib\request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File ~\.conda\envs\taller\Lib\urllib\request.py:563, in OpenerDirector.error(self, proto, *args)
#     561 if http_err:
#     562     args = (dict, 'default', 'http_error_default') + orig_args
# --> 563     return self._call_chain(*args)
#
# File ~\.conda\envs\taller\Lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File ~\.conda\envs\taller\Lib\urllib\request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 404: Not Found

# %%
df.columns
# Out:
# Index(['ID1', 'CASEID', 'V201', 'V202', 'V203', 'V204', 'V205', 'V206', 'V207',
#        'V208',
#        ...
#        'QD333_4', 'QD333_5', 'QD333_6', 'V190', 'V191', 'UBIGEO', 'V022',
#        'V005', 'mujeres12a49', 'factor'],
#       dtype='object', length=253)

# %%
variable_V213 =type('V213')
print(variable_V213)
# Out:
# <class 'str'>

# %%
df['V213']
# Out:
# 0       No o no está segura
# 1       No o no está segura
# 2       No o no está segura
# 3                        Sí
# 4       No o no está segura
#                ...
# 4680    No o no está segura
# 4681    No o no está segura
# 4682    No o no está segura
# 4683    No o no está segura
# 4684    No o no está segura
# Name: V213, Length: 4685, dtype: category
# Categories (2, object): ['No o no está segura' < 'Sí']

# %%
df['V213']=df['V213'].replace({'No o no está segura': 0, 'Sí': 1})

# %%
df['V213'] = pd.to_numeric(df['V213'], errors='coerce')

# %%
subset_df=df.groupby('V024')['V213'].sum().reset_index()
# Out:
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_8748\664851460.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   subset_df=df.groupby('V024')['V213'].sum().reset_index()

# %%
subset_df
# Out:
#               V024  V213
# 0         Amazonas     7
# 1           Ancash     2
# 2         Apurimac     4
# 3         Arequipa     2
# 4         Ayacucho     6
# 5        Cajamarca     8
# 6           Callao     3
# 7            Cusco     1
# 8     Huancavelica     3
# 9          Huanuco     9
# 10             Ica     9
# 11           Junin     6
# 12     La Libertad     4
# 13      Lambayeque     4
# 14            Lima     8
# 15          Loreto    14
# 16   Madre de Dios     3
# 17        Moquegua     2
# 18           Pasco     6
# 19           Piura     4
# 20            Puno     3
# 21      San Martin    12
# 22           Tacna     2
# 23          Tumbes     6
# 24         Ucayali    14

# %%
subset_df.rename(columns={'V024': 'DEPARTAMEN'}, inplace=True)

# %%
subset_df['DEPARTAMEN']=subset_df['DEPARTAMEN'].str.upper()

# %%
subset_df['DEPARTAMEN'].info
# Out:
# <bound method Series.info of 0           AMAZONAS
# 1             ANCASH
# 2           APURIMAC
# 3           AREQUIPA
# 4           AYACUCHO
# 5          CAJAMARCA
# 6             CALLAO
# 7              CUSCO
# 8       HUANCAVELICA
# 9            HUANUCO
# 10               ICA
# 11             JUNIN
# 12       LA LIBERTAD
# 13        LAMBAYEQUE
# 14              LIMA
# 15            LORETO
# 16     MADRE DE DIOS
# 17          MOQUEGUA
# 18             PASCO
# 19             PIURA
# 20              PUNO
# 21        SAN MARTIN
# 22             TACNA
# 23            TUMBES
# 24           UCAYALI
# Name: DEPARTAMEN, dtype: object>

# %%
subset_df['DEPARTAMEN']=subset_df['DEPARTAMEN'].str.strip()

# %%
#Data Scaling
columnsToScale=['V213'] # you can add more columns

from sklearn import preprocessing

minmaxSc = preprocessing.MinMaxScaler(feature_range=(0, 10))

minmaxResult = minmaxSc.fit_transform(subset_df[columnsToScale])

minmaxResult
# Out:
# array([[ 4.61538462],
#        [ 0.76923077],
#        [ 2.30769231],
#        [ 0.76923077],
#        [ 3.84615385],
#        [ 5.38461538],
#        [ 1.53846154],
#        [ 0.        ],
#        [ 1.53846154],
#        [ 6.15384615],
#        [ 6.15384615],
#        [ 3.84615385],
#        [ 2.30769231],
#        [ 2.30769231],
#        [ 5.38461538],
#        [10.        ],
#        [ 1.53846154],
#        [ 0.76923077],
#        [ 3.84615385],
#        [ 2.30769231],
#        [ 1.53846154],
#        [ 8.46153846],
#        [ 0.76923077],
#        [ 3.84615385],
#        [10.        ]])

# %%
subset_df['Total_minMax']=minmaxResult

# %%
import geopandas as gpd
import os

Peru=gpd.read_file(os.path.join("mapas", "peruMaps.gpkg"))

# %%
Peru.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   IDDPTO      25 non-null     object
#  1   DEPARTAMEN  25 non-null     object
#  2   CAPITAL     25 non-null     object
#  3   FUENTE      25 non-null     object
#  4   geometry    25 non-null     geometry
# dtypes: geometry(1), object(4)
# memory usage: 1.1+ KB

# %%
Peru.plot()
# Out:
# <Axes: >

# %%
print(Peru)
# Out:
#    IDDPTO     DEPARTAMEN           CAPITAL FUENTE  \
# 0      01       AMAZONAS       CHACHAPOYAS   INEI
# 1      02         ANCASH            HUARAZ   INEI
# 2      03       APURIMAC           ABANCAY   INEI
# 3      04       AREQUIPA          AREQUIPA   INEI
# 4      05       AYACUCHO          AYACUCHO   INEI
# 5      06      CAJAMARCA         CAJAMARCA   INEI
# 6      07         CALLAO            CALLAO   INEI
# 7      08          CUSCO             CUSCO   INEI
# 8      09   HUANCAVELICA      HUANCAVELICA   INEI
# 9      10        HUANUCO           HUANUCO   INEI
# 10     11            ICA               ICA   INEI
# 11     12          JUNIN          HUANCAYO   INEI
# 12     13    LA LIBERTAD          TRUJILLO   INEI
# 13     14     LAMBAYEQUE          CHICLAYO   INEI
# 14     15           LIMA              LIMA   INEI
# 15     16         LORETO           IQUITOS   INEI
# 16     17  MADRE DE DIOS  PUERTO MALDONADO   INEI
# 17     18       MOQUEGUA          MOQUEGUA   INEI
# 18     19          PASCO    CERRO DE PASCO   INEI
# 19     20          PIURA             PIURA   INEI
# 20     21           PUNO              PUNO   INEI
# 21     22     SAN MARTIN         MOYOBAMBA   INEI
# 22     23          TACNA             TACNA   INEI
# 23     24         TUMBES            TUMBES   INEI
# 24     25        UCAYALI          PUCALLPA   INEI
#
#                                              geometry
# 0   POLYGON ((-77.81211 -2.98962, -77.81332 -2.990...
# 1   POLYGON ((-77.64692 -8.05086, -77.64669 -8.052...
# 2   POLYGON ((-73.74632 -13.17456, -73.74570 -13.1...
# 3   POLYGON ((-71.98109 -14.64062, -71.98093 -14.6...
# 4   POLYGON ((-74.34843 -12.17503, -74.35000 -12.1...
# 5   POLYGON ((-78.70034 -4.62769, -78.69817 -4.629...
# 6   POLYGON ((-77.13521 -11.81782, -77.13516 -11.8...
# 7   POLYGON ((-72.97280 -11.25189, -72.97134 -11.2...
# 8   POLYGON ((-74.57118 -11.98710, -74.57095 -11.9...
# 9   POLYGON ((-76.00486 -8.30517, -76.00301 -8.305...
# 10  POLYGON ((-75.61136 -12.96649, -75.61103 -12.9...
# 11  POLYGON ((-75.03564 -10.68232, -75.03436 -10.6...
# 12  POLYGON ((-77.75753 -6.96579, -77.75638 -6.967...
# 13  POLYGON ((-79.88373 -5.49283, -79.88265 -5.494...
# 14  MULTIPOLYGON (((-76.78117 -12.40917, -76.78144...
# 15  POLYGON ((-75.10004 -0.08096, -75.09485 -0.081...
# 16  POLYGON ((-70.61346 -10.12964, -70.61359 -10.2...
# 17  POLYGON ((-70.79388 -15.98721, -70.79486 -15.9...
# 18  POLYGON ((-74.68005 -9.44727, -74.67872 -9.448...
# 19  POLYGON ((-80.48552 -4.08443, -80.48403 -4.085...
# 20  MULTIPOLYGON (((-68.81422 -16.34799, -68.91839...
# 21  POLYGON ((-77.71678 -5.41597, -77.71270 -5.416...
# 22  POLYGON ((-70.26604 -16.77955, -70.26474 -16.7...
# 23  POLYGON ((-80.28521 -3.41276, -80.28406 -3.412...
# 24  POLYGON ((-74.47145 -7.27617, -74.47052 -7.277...

# %%
Peru.columns
# Out:
# Index(['IDDPTO', 'DEPARTAMEN', 'CAPITAL', 'FUENTE', 'geometry'], dtype='object')

# %%
theMap=Peru.merge(subset_df,on='DEPARTAMEN')
# here it is:
theMap
# Out:
#    IDDPTO     DEPARTAMEN           CAPITAL FUENTE  \
# 0      01       AMAZONAS       CHACHAPOYAS   INEI
# 1      02         ANCASH            HUARAZ   INEI
# 2      03       APURIMAC           ABANCAY   INEI
# 3      04       AREQUIPA          AREQUIPA   INEI
# 4      05       AYACUCHO          AYACUCHO   INEI
# 5      06      CAJAMARCA         CAJAMARCA   INEI
# 6      07         CALLAO            CALLAO   INEI
# 7      08          CUSCO             CUSCO   INEI
# 8      09   HUANCAVELICA      HUANCAVELICA   INEI
# 9      10        HUANUCO           HUANUCO   INEI
# 10     11            ICA               ICA   INEI
# 11     12          JUNIN          HUANCAYO   INEI
# 12     13    LA LIBERTAD          TRUJILLO   INEI
# 13     14     LAMBAYEQUE          CHICLAYO   INEI
# 14     15           LIMA              LIMA   INEI
# 15     16         LORETO           IQUITOS   INEI
# 16     17  MADRE DE DIOS  PUERTO MALDONADO   INEI
# 17     18       MOQUEGUA          MOQUEGUA   INEI
# 18     19          PASCO    CERRO DE PASCO   INEI
# 19     20          PIURA             PIURA   INEI
# 20     21           PUNO              PUNO   INEI
# 21     22     SAN MARTIN         MOYOBAMBA   INEI
# 22     23          TACNA             TACNA   INEI
# 23     24         TUMBES            TUMBES   INEI
# 24     25        UCAYALI          PUCALLPA   INEI
#
#                                              geometry  V213  Total_minMax
# 0   POLYGON ((-77.81211 -2.98962, -77.81332 -2.990...     7      4.615385
# 1   POLYGON ((-77.64692 -8.05086, -77.64669 -8.052...     2      0.769231
# 2   POLYGON ((-73.74632 -13.17456, -73.74570 -13.1...     4      2.307692
# 3   POLYGON ((-71.98109 -14.64062, -71.98093 -14.6...     2      0.769231
# 4   POLYGON ((-74.34843 -12.17503, -74.35000 -12.1...     6      3.846154
# 5   POLYGON ((-78.70034 -4.62769, -78.69817 -4.629...     8      5.384615
# 6   POLYGON ((-77.13521 -11.81782, -77.13516 -11.8...     3      1.538462
# 7   POLYGON ((-72.97280 -11.25189, -72.97134 -11.2...     1      0.000000
# 8   POLYGON ((-74.57118 -11.98710, -74.57095 -11.9...     3      1.538462
# 9   POLYGON ((-76.00486 -8.30517, -76.00301 -8.305...     9      6.153846
# 10  POLYGON ((-75.61136 -12.96649, -75.61103 -12.9...     9      6.153846
# 11  POLYGON ((-75.03564 -10.68232, -75.03436 -10.6...     6      3.846154
# 12  POLYGON ((-77.75753 -6.96579, -77.75638 -6.967...     4      2.307692
# 13  POLYGON ((-79.88373 -5.49283, -79.88265 -5.494...     4      2.307692
# 14  MULTIPOLYGON (((-76.78117 -12.40917, -76.78144...     8      5.384615
# 15  POLYGON ((-75.10004 -0.08096, -75.09485 -0.081...    14     10.000000
# 16  POLYGON ((-70.61346 -10.12964, -70.61359 -10.2...     3      1.538462
# 17  POLYGON ((-70.79388 -15.98721, -70.79486 -15.9...     2      0.769231
# 18  POLYGON ((-74.68005 -9.44727, -74.67872 -9.448...     6      3.846154
# 19  POLYGON ((-80.48552 -4.08443, -80.48403 -4.085...     4      2.307692
# 20  MULTIPOLYGON (((-68.81422 -16.34799, -68.91839...     3      1.538462
# 21  POLYGON ((-77.71678 -5.41597, -77.71270 -5.416...    12      8.461538
# 22  POLYGON ((-70.26604 -16.77955, -70.26474 -16.7...     2      0.769231
# 23  POLYGON ((-80.28521 -3.41276, -80.28406 -3.412...     6      3.846154
# 24  POLYGON ((-74.47145 -7.27617, -74.47052 -7.277...    14     10.000000

# %%
#CLOROPLETHS
theMap['Total_minMax'].describe()
# Out:
# count    25.000000
# mean      3.600000
# std       2.849963
# min       0.000000
# 25%       1.538462
# 50%       2.307692
# 75%       5.384615
# max      10.000000
# Name: Total_minMax, dtype: float64

# %%
theMap.Total_minMax.hist()
# Out:
# <Axes: >

# %%
theMap.boxplot(column=['Total_minMax'])
# Out:
# <Axes: >

# %%
pip install numba
# Out:
# Collecting numba
#   Obtaining dependency information for numba from https://files.pythonhosted.org/packages/e8/1c/5d65ac922a4f9a6f90a10207b818e22e4d48a782af6574a6e7a50fae074d/numba-0.58.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading numba-0.58.0-cp311-cp311-win_amd64.whl.metadata (2.8 kB)
# Collecting llvmlite<0.42,>=0.41.0dev0 (from numba)
#   Obtaining dependency information for llvmlite<0.42,>=0.41.0dev0 from https://files.pythonhosted.org/packages/14/3b/f9665a46486f70a7cbb6237308e49e18ed42e4763f4e92e92cd37ea67ead/llvmlite-0.41.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading llvmlite-0.41.0-cp311-cp311-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: numpy<1.26,>=1.21 in c:\users\usuario\anaconda3\envs\proyectomagallanes\lib\site-packages (from numba) (1.25.2)
# Downloading numba-0.58.0-cp311-cp311-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#     --------------------------------------- 0.0/2.6 MB 653.6 kB/s eta 0:00:04
#    - -------------------------------------- 0.1/2.6 MB 653.6 kB/s eta 0:00:04
#    - -------------------------------------- 0.1/2.6 MB 653.6 kB/s eta 0:00:04
#    - -------------------------------------- 0.1/2.6 MB 435.7 kB/s eta 0:00:06
#    - -------------------------------------- 0.1/2.6 MB 435.7 kB/s eta 0:00:06
#    -- ------------------------------------- 0.2/2.6 MB 583.1 kB/s eta 0:00:05
#    --- ------------------------------------ 0.3/2.6 MB 785.2 kB/s eta 0:00:03
#    ---- ----------------------------------- 0.3/2.6 MB 819.2 kB/s eta 0:00:03
#    ------ --------------------------------- 0.4/2.6 MB 994.9 kB/s eta 0:00:03
#    ------- -------------------------------- 0.5/2.6 MB 1.0 MB/s eta 0:00:03
#    ------- -------------------------------- 0.5/2
1 MB 1.2 MB/s eta 0:00:04
#    ---------------------------------- ----- 24.5/28.1 MB 1.2 MB/s eta 0:00:04
#    ---------------------------------- ----- 24.5/28.1 MB 1.1 MB/s eta 0:00:04
#    ---------------------------------- ----- 24.6/28.1 MB 1.1 MB/s eta 0:00:04
#    ----------------------------------- ---- 24.6/28.1 MB 1.1 MB/s eta 0:00:04
#    ----------------------------------- ---- 24.7/28.1 MB 1.2 MB/s eta 0:00:03
#    ----------------------------------- ---- 24.7/28.1 MB 1.1 MB/s eta 0:00:03
#    ----------------------------------- ---- 24.7/28.1 MB 1.1 MB/s eta 0:00:03
#    ----------------------------------- ---- 24.8/28.1 MB 1.1 MB/s eta 0:00:03
#    ----------------------------------- ---- 24.8/28.1 MB 1.1 MB/s eta 0:00:03
#    ----------------------------------- ---- 24.9/28.1 MB 1.2 MB/s eta 0:00:03
#    ----------------------------------- ---- 25.0/28.1 MB 1.2 MB/s eta 0:00:03
#    ----------------------------------- ---- 25.0/28.1 MB 1.2 MB/s eta 0:00:03
#    ----------------------------------- ---- 25.0/28.1 MB 1.2 MB/s eta 0:00:03
#    ----------------------------------- ---- 25.1/28.1 MB 1.2 MB/s eta 0:00:03
#    ----------------------------------- ---- 25.1/28.1 MB 1.2 MB/s eta 0:00:03
#    ----------------------------------- ---- 25.2/28.1 MB 1.2 MB/s eta 0:00:03
#    ----------------------------------- ---- 25.2/28.1 MB 1.2 MB/s eta 0:00:03
#    ----------------------------------- ---- 25.2/28.1 MB 1.2 MB/s eta 0:00:03
#    ------------------------------------ --- 25.3/28.1 MB 1.2 MB/s eta 0:00:03
#    ------------------------------------ --- 25.4/28.1 MB 1.2 MB/s eta 0:00:03
#    ------------------------------------ --- 25.4/28.1 MB 1.2 MB/s eta 0:00:03
#    ------------------------------------ --- 25.4/28.1 MB 1.2 MB/s eta 0:00:03
#    ------------------------------------ --- 25.4/28.1 MB 1.2 MB/s eta 0:00:03
#    ------------------------------------ --- 25.4/28.1 MB 1.2 MB/s eta 0:00:03
#    ------------------------------------ --- 25.5/28.1 MB 1.2 MB/s eta 0:00:03
#    ------------------------------------ --- 25.5/28.1 MB 1.2 MB/s eta 0:00:03
#    ------------------------------------ --- 25.5/28.1 MB 1.2 MB/s eta 0:00:03
#    ------------------------------------ --- 25.5/28.1 MB 1.2 MB/s eta 0:00:03
#    ------------------------------------ --- 25.6/28.1 MB 1.2 MB/s eta 0:00:03
#    ------------------------------------ --- 25.6/28.1 MB 1.2 MB/s eta 0:00:03
#    ------------------------------------ --- 25.6/28.1 MB 1.2 MB/s eta 0:00:03
#    ------------------------------------ --- 25.6/28.1 MB 1.2 MB/s eta 0:00:03
#    ------------------------------------ --- 25.6/28.1 MB 1.2 MB/s eta 0:00:03
#    ------------------------------------ --- 25.6/28.1 MB 1.2 MB/s eta 0:00:03
#    ------------------------------------ --- 25.7/28.1 MB 1.1 MB/s eta 0:00:03
#    ------------------------------------ --- 25.7/28.1 MB 1.1 MB/s eta 0:00:03
#    ------------------------------------ --- 25.7/28.1 MB 1.1 MB/s eta 0:00:03
#    ------------------------------------ --- 25.7/28.1 MB 1.1 MB/s eta 0:00:03
#    ------------------------------------ --- 25.7/28.1 MB 1.1 MB/s eta 0:00:03
#    ------------------------------------ --- 25.7/28.1 MB 1.1 MB/s eta 0:00:03
#    ------------------------------------ --- 25.8/28.1 MB 1.1 MB/s eta 0:00:03
#    ------------------------------------ --- 25.8/28.1 MB 1.1 MB/s eta 0:00:03
#    ------------------------------------ --- 25.8/28.1 MB 1.1 MB/s eta 0:00:03
#    ------------------------------------ --- 25.8/28.1 MB 1.1 MB/s eta 0:00:03
#    ------------------------------------ --- 25.8/28.1 MB 1.1 MB/s eta 0:00:03
#    ------------------------------------ --- 25.9/28.1 MB 1.1 MB/s eta 0:00:03
#    ------------------------------------ --- 25.9/28.1 MB 1.1 MB/s eta 0:00:03
#    ------------------------------------ --- 26.0/28.1 MB 1.1 MB/s eta 0:00:02
#    ------------------------------------ --- 26.0/28.1 MB 1.1 MB/s eta 0:00:02
#    ------------------------------------ --- 26.0/28.1 MB 1.1 MB/s eta 0:00:02
#    ------------------------------------- -- 26.1/28.1 MB 1.1 MB/s eta 0:00:02
#    ------------------------------------- -- 26.1/28.1 MB 1.1 MB/s eta 0:00:02
#    ------------------------------------- -- 26.1/28.1 MB 1.1 MB/s eta 0:00:02
#    ------------------------------------- -- 26.1/28.1 MB 1.1 MB/s eta 0:00:02
#    ------------------------------------- -- 26.1/28.1 MB 1.1 MB/s eta 0:00:02
#    ------------------------------------- -- 26.1/28.1 MB 1.1 MB/s eta 0:00:02
#    ------------------------------------- -- 26.1/28.1 MB 1.1 MB/s eta 0:00:02
#    ------------------------------------- -- 26.2/28.1 MB 1.1 MB/s eta 0:00:02
#    ------------------------------------- -- 26.2/28.1 MB 1.1 MB/s eta 0:00:02
#    ------------------------------------- -- 26.2/28.1 MB 1.0 MB/s eta 0:00:02
#    ------------------------------------- -- 26.3/28.1 MB 1.0 MB/s eta 0:00:02
#    ------------------------------------- -- 26.3/28.1 MB 1.0 MB/s eta 0:00:02
#    ------------------------------------- -- 26.3/28.1 MB 1.0 MB/s eta 0:00:02
#    ------------------------------------- -- 26.3/28.1 MB 1.0 MB/s eta 0:00:02
#    ------------------------------------- -- 26.3/28.1 MB 1.0 MB/s eta 0:00:02
#    ------------------------------------- -- 26.3/28.1 MB 1.0 MB/s eta 0:00:02
#    ------------------------------------- -- 26.3/28.1 MB 1.0 MB/s eta 0:00:02
#    ------------------------------------- -- 26.3/28.1 MB 1.0 MB/s eta 0:00:02
#    ------------------------------------- -- 26.4/28.1 MB 1.0 MB/s eta 0:00:02
#    ------------------------------------- -- 26.4/28.1 MB 1.0 MB/s eta 0:00:02
#    ------------------------------------- -- 26.5/28.1 MB 1.0 MB/s eta 0:00:02
#    ------------------------------------- -- 26.5/28.1 MB 1.0 MB/s eta 0:00:02
#    ------------------------------------- -- 26.6/28.1 MB 1.0 MB/s eta 0:00:02
#    ------------------------------------- -- 26.7/28.1 MB 1.0 MB/s eta 0:00:02
#    -------------------------------------- - 26.7/28.1 MB 999.5 kB/s eta 0:00:02
#    -------------------------------------- - 26.8/28.1 MB 996.6 kB/s eta 0:00:02
#    -------------------------------------- - 26.9/28.1 MB 999.5 kB/s eta 0:00:02
#    -------------------------------------- - 26.9/28.1 MB 1.0 MB/s eta 0:00:02
#    -------------------------------------- - 27.0/28.1 MB 1.0 MB/s eta 0:00:02
#    -------------------------------------- - 27.0/28.1 MB 1.0 MB/s eta 0:00:02
#    -------------------------------------- - 27.1/28.1 MB 1.0 MB/s eta 0:00:02
#    -------------------------------------- - 27.1/28.1 MB 998.0 kB/s eta 0:00:01
#    -------------------------------------- - 27.2/28.1 MB 1.0 MB/s eta 0:00:01
#    -------------------------------------- - 27.3/28.1 MB 1.0 MB/s eta 0:00:01
#    -------------------------------------- - 27.4/28.1 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------  27.5/28.1 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------  27.5/28.1 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------  27.6/28.1 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------  27.6/28.1 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------  27.7/28.1 MB 999.5 kB/s eta 0:00:01
#    ---------------------------------------  27.7/28.1 MB 996.5 kB/s eta 0:00:01
#    ---------------------------------------  27.8/28.1 MB 998.0 kB/s eta 0:00:01
#    ---------------------------------------  27.9/28.1 MB 999.5 kB/s eta 0:00:01
#    ---------------------------------------  28.0/28.1 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------- 28.1/28.1 MB 991.9 kB/s eta 0:00:00
# Installing collected packages: llvmlite, numba
# Successfully installed llvmlite-0.41.0 numba-0.58.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import mapclassify 
import numpy as np

np.random.seed(12345) # so we all get the same results!

# let's try 5 intervals
K=5
theVar=theMap.Total_minMax
# same interval width, easy interpretation
ei5 = mapclassify.EqualInterval(theVar, k=K)
# same interval width based on standard deviation, easy - but not as the previous one, poor when high skewness
msd = mapclassify.StdMean(theVar)
# interval width varies, counts per interval are close, not easy to grasp, repeated values complicate cuts                                
q5=mapclassify.Quantiles(theVar,k=K)

# based on similarity, good for multimodal data 
mb5 = mapclassify.MaximumBreaks(theVar, k=K)
# based on similarity, good for skewed data
ht = mapclassify.HeadTailBreaks(theVar) # no K needed
# based on similarity, optimizer
fj5 = mapclassify.FisherJenks(theVar, k=K)
# based on similarity, optimizer
jc5 = mapclassify.JenksCaspall(theVar, k=K)
# based on similarity, optimizer
mp5 = mapclassify.MaxP(theVar, k=K)

# %%
class5 = q5, ei5,msd, ht, mb5, fj5, jc5, mp5
# Collect ADCM for each classifier
fits = np.array([ c.adcm for c in class5])
# Convert ADCM scores to a DataFrame
adcms = pd.DataFrame(fits)
# Add classifier names
adcms['classifier'] = [c.name for c in class5]
# Add column names to the ADCM
adcms.columns = ['ADCM', 'Classifier']

# %%
adcms.sort_values('ADCM').plot.barh(x='Classifier')
# Out:
# <Axes: ylabel='Classifier'>

# %%
theMap['Total_mb5'] = mb5.yb

# %%
import matplotlib.pyplot as plt

f, ax = plt.subplots(1, figsize=(10, 10))
theMap.plot(column='Total_mb5', 
        cmap='viridis', 
        categorical=True,
        edgecolor='white', 
        linewidth=0., 
        alpha=0.75, 
        legend=True,
        legend_kwds={'loc':3},
        ax=ax
       )

ax.set_axis_off()

# %%
theMap=theMap.to_crs(8858)

# %%
theMap['centroid']=theMap.geometry.centroid

# %%
# just the plot
base=theMap.plot(facecolor='white',
                     edgecolor='lightgrey',
                     linewidth=0.3,
                     figsize=(8,8))

# another column, with the size of the POINTS (based on "Total_ei5")
theMap["sizeOfMarker_ei5"]=[4**exp for exp in theMap["Total_mb5"]]

# now, plotting the centroids (declared as the geometry)!!!
theMap.set_geometry("centroid").plot(column="Total_mb5",
                                         categorical=True,
                                         markersize=theMap["sizeOfMarker_ei5"],
                                         cmap='Paired_r',
                                         legend=True,ax=base)
# Out:
# <Axes: >
