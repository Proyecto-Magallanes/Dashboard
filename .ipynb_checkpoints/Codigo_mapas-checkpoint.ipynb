# %%
import os, geopandas as gpd

peru2=gpd.read_file(os.path.join('','departamentos','DEPARTAMENTOS.shp'))
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File fiona\ogrext.pyx:136, in fiona.ogrext.gdal_open_vector()
#
# File fiona\_err.pyx:291, in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: C:\Users\USUARIO\Documents\Proyecto Magallanes\simpleplot\departamentos\DEPARTAMENTOS.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 import os, geopandas as gpd
# ----> 3 peru2=gpd.read_file(os.path.join('C:\\Users\\USUARIO\\Documents\\Proyecto Magallanes\\simpleplot','departamentos','DEPARTAMENTOS.shp'))
#
# File ~\.conda\envs\taller\Lib\site-packages\geopandas\io\file.py:281, in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     278     else:
#     279         path_or_bytes = filename
# ...

# %%
type(peru2)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
peru2.plot(facecolor="azure",#color of polygon fill
               edgecolor='black', #color of lines
               linewidth=0.1) #thickness of lines
# Out:
# <Axes: >

# %%
provincias=gpd.read_file(os.path.join('C:\\Users\\USUARIO\\Documents\\Proyecto Magallanes\\simpleplot','provincias','PROVINCIAS.shp'))

# %%
## Sale muy claro, no se ve nada
# provincias.plot(marker='.', # marker type
#            color='azure',
#            markersize=1,
#            alpha=0.9) # transparency
# Out:
# <Axes: >

# %%
provincias.plot(facecolor="azure", #color of polygon fill
              edgecolor='black', #color of lines
              linewidth=0.1) # thickness of lines
# Out:
# <Axes: >

# %%
peru2.crs==provincias.crs
# Out:
# True

# %%
import matplotlib.pyplot as plt

base = peru2.plot(facecolor="blue", edgecolor='black', linewidth=0.4,figsize=(5,5))
provincias.plot(marker='+', color='pink', markersize=15,ax=base)
plt.savefig(os.path.join('C','Users,\\USUARIO\\Documents\\Proyecto Magallanes\\Imagenes','peru2.jpg'))

# %%
peru2.to_file(os.path.join("C:\\Users\\USUARIO\\Documents\\Proyecto Magallanes\\Mapas","peruMaps2.gpkg"), layer='peru', driver="GPKG")
provincias.to_file(os.path.join("C:\\Users\\USUARIO\\Documents\\Proyecto Magallanes\\Mapas","peruMaps2.gpkg"), layer='prov', driver="GPKG")

# %%
peruMapa=gpd.read_file("https://github.com/Proyecto-Magallanes/Mapas/blob/2e1a5a351f4ec1fad2ec2e270d4e5a0016272378/peruMaps2.gpkg")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 peruMapa=gpd.read_file("https://github.com/Proyecto-Magallanes/Mapas/blob/2e1a5a351f4ec1fad2ec2e270d4e5a0016272378/peruMaps2.gpkg")
#
# File ~\anaconda3\envs\ProyectoMagallanes\Lib\site-packages\geopandas\io\file.py:281, in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     275 from_bytes = False
#     276 if _is_url(filename):
#     277     # if it is a url that supports random access -> pass through to
#     278     # pyogrio/fiona as is (to support downloading only part of the file)
#     279     # otherwise still download manually because pyogrio/fiona don't support
#     280     # all types of urls (https://github.com/geopandas/geopandas/issues/2908)
# --> 281     with urllib.request.urlopen(filename) as response:
# ...

# %%
from  fiona import listlayers

listlayers(peruMapa)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 3
#       1 from  fiona import listlayers
# ----> 3 listlayers(peruMapa)
#
# File ~\anaconda3\envs\ProyectoMagallanes\Lib\site-packages\fiona\env.py:457, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     454     session = DummySession()
#     456 with env_ctor(session=session):
# --> 457     return f(*args, **kwds)
#
# File ~\anaconda3\envs\ProyectoMagallanes\Lib\site-packages\fiona\__init__.py:434, in listlayers(fp, vfs, **kwargs)
#     431     fp = str(fp)
#     433 if not isinstance(fp, str):
# --> 434     raise TypeError("invalid path: %r" % fp)
#     435 if vfs and not isinstance(vfs, str):
#     436     raise TypeError("invalid vfs: %r" % vfs)
#
# TypeError: invalid path:    IDDPTO     DEPARTAMEN           CAPITAL FUENTE  \
# 0      01       AMAZONAS       CHACHAPOYAS   INEI
# ...

# %% [markdown]
# from  fiona import listlayers
#
# listlayers(peruMapa)

# %%
#Segundo parte del ejercicio
peru.crs.axis_info
# Out:
# [Axis(name=Geodetic latitude, abbrev=Lat, direction=north, unit_auth_code=EPSG, unit_code=9122, unit_name=degree),
#  Axis(name=Geodetic longitude, abbrev=Lon, direction=east, unit_auth_code=EPSG, unit_code=9122, unit_name=degree)]

# %%
peru.to_crs(3587).crs.axis_info
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 peru.to_crs(3587).crs.axis_info
#
# NameError: name 'peru' is not defined

# %%
from matplotlib import pyplot

fig, (ax1, ax2) = pyplot.subplots(ncols=2, sharex=False, sharey=False, figsize=(12,12))

# %%
fig, (ax1, ax2) = pyplot.subplots(ncols=2, sharex=False, sharey=False, figsize=(12,12))

peru.plot(ax=ax1, facecolor='lightgrey', edgecolor='black')
prov.plot(ax=ax2, facecolor='lightgrey', edgecolor='black',linewidth=0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 fig, (ax1, ax2) = pyplot.subplots(ncols=2, sharex=False, sharey=False, figsize=(12,12))
# ----> 3 peru.plot(ax=ax1, facecolor='lightgrey', edgecolor='black')
#       4 prov.plot(ax=ax2, facecolor='lightgrey', edgecolor='black',linewidth=0.2)
#
# NameError: name 'peru' is not defined

# %%
peru.centroid
# Out:
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_13840\1145804006.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   peru.centroid
# 0      POINT (-78.05489 -5.07073)
# 1      POINT (-77.66997 -9.40702)
# 2     POINT (-72.97538 -14.02814)
# 3     POINT (-72.47623 -15.84292)
# 4     POINT (-74.08367 -14.08861)
# 5      POINT (-78.74544 -6.43300)
# 6     POINT (-77.12585 -11.94033)
# 7     POINT (-72.16934 -13.18788)
# 8     POINT (-75.00278 -13.02439)
# 9      POINT (-76.02561 -9.41620)
# 10    POINT (-75.57358 -14.23430)
# 11    POINT (-74.87907 -11.53821)
# 12     POINT (-78.36834 -7.92141)
# 13     POINT (-79.82689 -6.34056)
# 14    POINT (-76.62717 -11.78557)
# 15     POINT (-74.42636 -4.11981)
# 16    POINT (-70.53469 -11.98086)
# 17    POINT (-70.83842 -16.85983)
# 18    POINT (-75.29991 -10.39887)
# 19     POINT (-80.33598 -5.12800)
# ...

# %%
peru.to_crs(1201).crs.axis_info
# Out:
# ---------------------------------------------------------------------------
# CRSError                                  Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 peru.to_crs(1201).crs.axis_info
#
# File ~\anaconda3\envs\ProyectoMagallanes\Lib\site-packages\geopandas\geodataframe.py:1425, in GeoDataFrame.to_crs(self, crs, epsg, inplace)
#    1423 else:
#    1424     df = self.copy()
# -> 1425 geom = df.geometry.to_crs(crs=crs, epsg=epsg)
#    1426 df.geometry = geom
#    1427 if not inplace:
#
# File ~\anaconda3\envs\ProyectoMagallanes\Lib\site-packages\geopandas\geoseries.py:1157, in GeoSeries.to_crs(self, crs, epsg)
#    1078 def to_crs(
#    1079     self, crs: Optional[Any] = None, epsg: Optional[int] = None
#    1080 ) -> GeoSeries:
#    1081     """Returns a ``GeoSeries`` with all geometries transformed to a new
#    1082     coordinate reference system.
#    1083
#    (...)
#    1154
#    1155     """
#    1156     return GeoSeries(
# ...

# %%
import pandas as pd 
hospitales=pd.read_csv(os.path.join("data","br-airports.csv"))

# some rows

infoairports.iloc[[0,1,2,3,-4,-3,-2,-1],:] #head and tail
