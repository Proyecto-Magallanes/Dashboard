# %%
import pandas as pd
import pyreadstat
import os

path= os.path.join('data','Endes_2022_N&M','786-Modulo1632' ,'RE223132.sav')
path3= os.path.join ('data','Endes_2022_MEF','786-Modulo1631','REC0111.sav')
data,endes = pyreadstat.read_sav(path)
data3, ende3 = pyreadstat.read_sav(path3)

# %%
variables =['CASEID','V213','V301', 'V302', 'V393', 'V3A06']

data1=data[variables]
data1 =pd.DataFrame(data1)
data1
# Out:
#                    CASEID  V213  V301  V302  V393  V3A06
# 0            000102201  2   0.0   NaN   3.0   0.0    1.0
# 1            000105201  2   0.0   NaN   2.0   0.0    NaN
# 2            000105201  3   0.0   NaN   0.0   0.0    NaN
# 3            000105201  4   0.0   NaN   0.0   0.0    NaN
# 4            000105301  1   0.0   NaN   3.0   0.0    NaN
# ...                   ...   ...   ...   ...   ...    ...
# 35782        434206201  2   0.0   NaN   3.0   0.0    NaN
# 35783        434206701  2   0.0   NaN   3.0   0.0    NaN
# 35784        434309701  3   0.0   NaN   0.0   0.0    NaN
# 35785        434309701  5   0.0   NaN   3.0   0.0    NaN
# 35786        434316101  2   0.0   NaN   3.0   0.0    NaN
#
# [35787 rows x 6 columns]

# %%
var = ['CASEID', 'UBIGEO', 'V013' ]
data3 =data3[var]
data3=pd.DataFrame(data3)
data3
# Out:
#                    CASEID  UBIGEO  V013
# 0            000102201  2  010101   2.0
# 1            000105201  2  010101   6.0
# 2            000105201  3  010101   2.0
# 3            000105201  4  010101   1.0
# 4            000105301  1  010101   4.0
# ...                   ...     ...   ...
# 38100        434206701  2  120302   5.0
# 38101        434304701  2  150136   NaN
# 38102        434309701  3  150136   4.0
# 38103        434309701  5  150136   5.0
# 38104        434316101  2  150136   2.0
#
# [38105 rows x 3 columns]

# %%
endes2022= pd.merge(data1, data3, on='CASEID')

# %%
endes2022
# Out:
#                    CASEID  V213  V301  V302  V393  V3A06  UBIGEO  V013
# 0            000102201  2   0.0   NaN   3.0   0.0    1.0  010101   2.0
# 1            000105201  2   0.0   NaN   2.0   0.0    NaN  010101   6.0
# 2            000105201  3   0.0   NaN   0.0   0.0    NaN  010101   2.0
# 3            000105201  4   0.0   NaN   0.0   0.0    NaN  010101   1.0
# 4            000105301  1   0.0   NaN   3.0   0.0    NaN  010101   4.0
# ...                   ...   ...   ...   ...   ...    ...     ...   ...
# 35782        434206201  2   0.0   NaN   3.0   0.0    NaN  120302   7.0
# 35783        434206701  2   0.0   NaN   3.0   0.0    NaN  120302   5.0
# 35784        434309701  3   0.0   NaN   0.0   0.0    NaN  150136   4.0
# 35785        434309701  5   0.0   NaN   3.0   0.0    NaN  150136   5.0
# 35786        434316101  2   0.0   NaN   3.0   0.0    NaN  150136   2.0
#
# [35787 rows x 8 columns]

# %%
endes2022['IDPROV'] = endes2022['UBIGEO'].astype(str).str[:4]

# %%
nuevos_nombres = {'V213': 'act_embara', 'V301': 'conoce_meto', 'V302': 'uso_meto', 'V393': 'visita_planfami', 'V3A04':'info_meto', 
                'V013': 'Edad'}
endes2022 = endes2022.rename(columns=nuevos_nombres)

# %%
endes2022['visita_planfami'].value_counts()
# Out:
# visita_planfami
# 0.0    33489
# 1.0     2298
# Name: count, dtype: int64

# %%
teens = endes2022['Edad']==1

solo_teens =endes2022[teens]
solo_teens
# Out:
#                    CASEID  act_embara  conoce_meto  uso_meto  visita_planfami  \
# 3            000105201  4         0.0          NaN       0.0              0.0
# 5            000105301  2         0.0          NaN       0.0              0.0
# 56           001005201  5         0.0          NaN       0.0              0.0
# 57           001006301  2         1.0          NaN       3.0              0.0
# 63           001106401  7         0.0          NaN       0.0              0.0
# ...                   ...         ...          ...       ...              ...
# 35748        434000201  3         0.0          NaN       0.0              0.0
# 35757        434005501  2         0.0          NaN       3.0              0.0
# 35759        434009701  3         0.0          NaN       0.0              0.0
# 35766        434103101  4         0.0          NaN       2.0              0.0
# 35778        434202701  2         0.0          NaN       3.0              0.0
#
#        V3A06  UBIGEO  Edad IDPROV
# 3        NaN  010101   1.0   0101
# 5        NaN  010101   1.0   0101
# 56       NaN  010203   1.0   0102
# 57       NaN  010203   1.0   0102
# 63       NaN  010201   1.0   0102
# ...      ...     ...   ...    ...
# 35748    NaN  250101   1.0   2501
# 35757    NaN  250101   1.0   2501
# 35759    NaN  250101   1.0   2501
# 35766    NaN  250103   1.0   2501
# 35778    NaN  120302   1.0   1203
#
# [4685 rows x 9 columns]

# %%
solo_teens = solo_teens.copy()
solo_teens['uso_meto'] = solo_teens['uso_meto'].replace({3: 'Si', 2: 'No', 1: 'Si', 0: 'No'})

# %%
si_por_provincia = solo_teens[solo_teens['uso_meto'] == 'Si']['IDPROV'].value_counts()

# Obtener el conteo total por provincia
total_por_provincia = solo_teens['IDPROV'].value_counts()

# Combinar las series en un nuevo DataFrame
data_prov = pd.DataFrame({'Si_Count': si_por_provincia, 'Total_Count': total_por_provincia})

# Calcular el porcentaje de 'Si' por provincia
data_prov['Porcentaje'] = (data_prov['Si_Count'] / data_prov['Total_Count']) * 100
data_prov
# Out:
#         Si_Count  Total_Count  Porcentaje
# IDPROV
# 0101         8.0           25   32.000000
# 0102        18.0           44   40.909091
# 0103         3.0            4   75.000000
# 0104        11.0           27   40.740741
# 0105        10.0           31   32.258065
# ...          ...          ...         ...
# 2402         8.0           19   42.105263
# 2403        17.0           42   40.476190
# 2501       102.0          192   53.125000
# 2502        13.0           24   54.166667
# 2503        16.0           23   69.565217
#
# [185 rows x 3 columns]

# %%
data_prov= data_prov.reset_index(drop=False).\
             rename_axis(index=None, columns=None) # no name for indexes
data_prov
# Out:
#     IDPROV  Si_Count  Total_Count  Porcentaje
# 0     0101       8.0           25   32.000000
# 1     0102      18.0           44   40.909091
# 2     0103       3.0            4   75.000000
# 3     0104      11.0           27   40.740741
# 4     0105      10.0           31   32.258065
# ..     ...       ...          ...         ...
# 180   2402       8.0           19   42.105263
# 181   2403      17.0           42   40.476190
# 182   2501     102.0          192   53.125000
# 183   2502      13.0           24   54.166667
# 184   2503      16.0           23   69.565217
#
# [185 rows x 4 columns]

# %%
data_prov = data_prov.fillna(0)

# %%
#Data Scaling
columnsToScale=['Porcentaje'] # you can add more columns

from sklearn import preprocessing

minmaxSc = preprocessing.MinMaxScaler(feature_range=(0, 10))

minmaxResult = minmaxSc.fit_transform(data_prov[columnsToScale])

data_prov['Total_minMax_2022']=minmaxResult[:, 0]
data_prov
# Out:
#     IDPROV  Si_Count  Total_Count  Porcentaje  Total_minMax_2022
# 0     0101       8.0           25   32.000000           3.200000
# 1     0102      18.0           44   40.909091           4.090909
# 2     0103       3.0            4   75.000000           7.500000
# 3     0104      11.0           27   40.740741           4.074074
# 4     0105      10.0           31   32.258065           3.225806
# ..     ...       ...          ...         ...                ...
# 180   2402       8.0           19   42.105263           4.210526
# 181   2403      17.0           42   40.476190           4.047619
# 182   2501     102.0          192   53.125000           5.312500
# 183   2502      13.0           24   54.166667           5.416667
# 184   2503      16.0           23   69.565217           6.956522
#
# [185 rows x 5 columns]

# %%
#Empezamos con el Mapa
import geopandas as gpd
import os

Peru=gpd.read_file(os.path.join("mapas", "peruMaps.gpkg"), layer='prov')
Peru["PROVINCIA"] = Peru["PROVINCIA"].str.strip()
Peru
# Out:
#     IDDPTO DEPARTAMEN IDPROV         PROVINCIA               CAPITAL FUENTE  \
# 0       01   AMAZONAS   0101       CHACHAPOYAS           CHACHAPOYAS   INEI
# 1       01   AMAZONAS   0102             BAGUA                 BAGUA   INEI
# 2       01   AMAZONAS   0103           BONGARA              JUMBILLA   INEI
# 3       01   AMAZONAS   0104      CONDORCANQUI  SANTA MARIA DE NIEVA   INEI
# 4       01   AMAZONAS   0105              LUYA                 LAMUD   INEI
# ..     ...        ...    ...               ...                   ...    ...
# 191     24     TUMBES   2403         ZARUMILLA             ZARUMILLA   INEI
# 192     25    UCAYALI   2501  CORONEL PORTILLO              PUCALLPA   INEI
# 193     25    UCAYALI   2502           ATALAYA               ATALAYA   INEI
# 194     25    UCAYALI   2503        PADRE ABAD              AGUAYTIA   INEI
# 195     25    UCAYALI   2504             PURUS             ESPERANZA   INEI
#
#                                               geometry
# 0    POLYGON ((-77.72614 -5.94354, -77.72486 -5.943...
# 1    POLYGON ((-78.61909 -4.51001, -78.61802 -4.510...
# 2    POLYGON ((-77.72759 -5.14030, -77.72361 -5.140...
# 3    POLYGON ((-77.81211 -2.98962, -77.81332 -2.990...
# 4    POLYGON ((-78.13023 -5.90370, -78.13011 -5.904...
# ..                                                 ...
# 191  POLYGON ((-80.28521 -3.41276, -80.28406 -3.412...
# 192  POLYGON ((-74.47145 -7.27617, -74.47052 -7.277...
# 193  POLYGON ((-73.18146 -9.41174, -73.13475 -9.411...
# 194  POLYGON ((-75.43663 -8.22999, -75.43651 -8.230...
# 195  POLYGON ((-70.50719 -9.42663, -70.50693 -9.426...
#
# [196 rows x 7 columns]

# %%
theMap=Peru.merge(data_prov, on=["IDPROV"], how="left")
theMap
# Out:
#     IDDPTO DEPARTAMEN IDPROV         PROVINCIA               CAPITAL FUENTE  \
# 0       01   AMAZONAS   0101       CHACHAPOYAS           CHACHAPOYAS   INEI
# 1       01   AMAZONAS   0102             BAGUA                 BAGUA   INEI
# 2       01   AMAZONAS   0103           BONGARA              JUMBILLA   INEI
# 3       01   AMAZONAS   0104      CONDORCANQUI  SANTA MARIA DE NIEVA   INEI
# 4       01   AMAZONAS   0105              LUYA                 LAMUD   INEI
# ..     ...        ...    ...               ...                   ...    ...
# 191     24     TUMBES   2403         ZARUMILLA             ZARUMILLA   INEI
# 192     25    UCAYALI   2501  CORONEL PORTILLO              PUCALLPA   INEI
# 193     25    UCAYALI   2502           ATALAYA               ATALAYA   INEI
# 194     25    UCAYALI   2503        PADRE ABAD              AGUAYTIA   INEI
# 195     25    UCAYALI   2504             PURUS             ESPERANZA   INEI
#
#                                               geometry  Si_Count  Total_Count  \
# 0    POLYGON ((-77.72614 -5.94354, -77.72486 -5.943...       8.0         25.0
# 1    POLYGON ((-78.61909 -4.51001, -78.61802 -4.510...      18.0         44.0
# 2    POLYGON ((-77.72759 -5.14030, -77.72361 -5.140...       3.0          4.0
# 3    POLYGON ((-77.81211 -2.98962, -77.81332 -2.990...      11.0         27.0
# 4    POLYGON ((-78.13023 -5.90370, -78.13011 -5.904...      10.0         31.0
# ..                                                 ...       ...          ...
# 191  POLYGON ((-80.28521 -3.41276, -80.28406 -3.412...      17.0         42.0
# 192  POLYGON ((-74.47145 -7.27617, -74.47052 -7.277...     102.0        192.0
# 193  POLYGON ((-73.18146 -9.41174, -73.13475 -9.411...      13.0         24.0
# 194  POLYGON ((-75.43663 -8.22999, -75.43651 -8.230...      16.0         23.0
# 195  POLYGON ((-70.50719 -9.42663, -70.50693 -9.426...       NaN          NaN
#
#      Porcentaje  Total_minMax_2022
# 0     32.000000           3.200000
# 1     40.909091           4.090909
# 2     75.000000           7.500000
# 3     40.740741           4.074074
# 4     32.258065           3.225806
# ..          ...                ...
# 191   40.476190           4.047619
# 192   53.125000           5.312500
# 193   54.166667           5.416667
# 194   69.565217           6.956522
# 195         NaN                NaN
#
# [196 rows x 11 columns]

# %%
theMap= theMap.fillna(0)

# %%
#Intervalos
import mapclassify 
import numpy as np

np.random.seed(12345) # so we all get the same results!

k=4

# let's try 5 intervals
theVar2022=theMap.Total_minMax_2022
# based on similarity, optimizer
mp52022 = mapclassify.MaxP(theVar2022, k=4)

# %%
theMap['Total_mp52022'] = mp52022.yb

# %%
changes={0:"0_Muy Bajo", 1:"1_Bajo", 2:"2_Alto", 3:"3_Muy Alto"}
theMap[['Total_mp52022']]=theMap.loc[:,['Total_mp52022']].replace(to_replace=changes)

# %%
theMap
# Out:
#     IDDPTO DEPARTAMEN IDPROV         PROVINCIA               CAPITAL FUENTE  \
# 0       01   AMAZONAS   0101       CHACHAPOYAS           CHACHAPOYAS   INEI
# 1       01   AMAZONAS   0102             BAGUA                 BAGUA   INEI
# 2       01   AMAZONAS   0103           BONGARA              JUMBILLA   INEI
# 3       01   AMAZONAS   0104      CONDORCANQUI  SANTA MARIA DE NIEVA   INEI
# 4       01   AMAZONAS   0105              LUYA                 LAMUD   INEI
# ..     ...        ...    ...               ...                   ...    ...
# 191     24     TUMBES   2403         ZARUMILLA             ZARUMILLA   INEI
# 192     25    UCAYALI   2501  CORONEL PORTILLO              PUCALLPA   INEI
# 193     25    UCAYALI   2502           ATALAYA               ATALAYA   INEI
# 194     25    UCAYALI   2503        PADRE ABAD              AGUAYTIA   INEI
# 195     25    UCAYALI   2504             PURUS             ESPERANZA   INEI
#
#                                               geometry  Si_Count  Total_Count  \
# 0    POLYGON ((-77.72614 -5.94354, -77.72486 -5.943...       8.0         25.0
# 1    POLYGON ((-78.61909 -4.51001, -78.61802 -4.510...      18.0         44.0
# 2    POLYGON ((-77.72759 -5.14030, -77.72361 -5.140...       3.0          4.0
# 3    POLYGON ((-77.81211 -2.98962, -77.81332 -2.990...      11.0         27.0
# 4    POLYGON ((-78.13023 -5.90370, -78.13011 -5.904...      10.0         31.0
# ..                                                 ...       ...          ...
# 191  POLYGON ((-80.28521 -3.41276, -80.28406 -3.412...      17.0         42.0
# 192  POLYGON ((-74.47145 -7.27617, -74.47052 -7.277...     102.0        192.0
# 193  POLYGON ((-73.18146 -9.41174, -73.13475 -9.411...      13.0         24.0
# 194  POLYGON ((-75.43663 -8.22999, -75.43651 -8.230...      16.0         23.0
# 195  POLYGON ((-70.50719 -9.42663, -70.50693 -9.426...       0.0          0.0
#
#      Porcentaje  Total_minMax_2022 Total_mp52022
# 0     32.000000           3.200000    0_Muy Bajo
# 1     40.909091           4.090909        1_Bajo
# 2     75.000000           7.500000    3_Muy Alto
# 3     40.740741           4.074074        1_Bajo
# 4     32.258065           3.225806    0_Muy Bajo
# ..          ...                ...           ...
# 191   40.476190           4.047619        1_Bajo
# 192   53.125000           5.312500    3_Muy Alto
# 193   54.166667           5.416667    3_Muy Alto
# 194   69.565217           6.956522    3_Muy Alto
# 195    0.000000           0.000000    0_Muy Bajo
#
# [196 rows x 12 columns]

# %%
theMap.to_file(os.path.join("mapas","Mapa_uso_metodos_2022.gpkg"), layer='peru', driver="GPKG")

# %%
theMap.to_excel(os.path.join("data", "data_uso_metodos_2022.xlsx"))
